# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                  society            sector  price  \
# 0          flat            m3m sierra 68         sector 68   1.05
# 1          flat  aipl the peaceful homes        sector 70a   2.40
# 2          flat        suncity avenue 76         sector 76   0.75
# 3         house  ansal sushant lok plots         sector 43  11.50
# 4          flat      ashok vihar phase 2  sector 3 phase 2   0.28
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8536.0  1230.0  Super Built up area 1230(114.27 sq.m.)Built Up...
# 1         11162.0  2150.0             Super Built up area 2150(199.74 sq.m.)
# 2         10204.0   735.0               Super Built up area 735(68.28 sq.m.)
# 3         17692.0  6500.0  Plot area 3762(349.5 sq.m.)Built Up area: 9000...
# 4          4307.0   650.0  Super Built up area 650(60.39 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        2         2       2      11.0  North-East        New Property
# 1        3         3       3      11.0  South-West      Relatively New
# 2        2         2       2      11.0         NaN  Under Construction
# 3        7         8      3+       3.0         NaN        Old Property
# 4        2         2       1       3.0       North      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1230.0         1200.0       1000.0           0             0
# 1               2150.0            NaN          NaN           0             1
# 2                735.0            NaN          NaN           0             0
# 3                  NaN         9000.0       6500.0           0             1
# 4                650.0            NaN        550.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0           127
# 1           0           0       0                1           108
# 2           0           0       0                1            57
# 3           1           1       0                0            31
# 4           0           0       0                1            64

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# C:\Users\Vaibhav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 3679         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 869          house                                        independent
# 1817         house                                        independent
# 3401         house                                     dlf city plots
# 1604         house                                   suncity township
# 3654         house                             emaar the palm springs
# 1821         house                                        independent
# 132          house                                 vipul tatvam villa
# 1018         house                             luxury dlf city floors
# 1742         house                                        independent
# 1181         house                                     dlf city plots
# 2768         house                                 vipul tatvam villa
# 1710         house                                        independent
# 2653         house                                        independent
# 1652         house                                     dlf city plots
# 673          house                                 emaar mgf marbella
# 592          house                                        independent
# 3018         house                                 vipul tatvam villa
# 1949         house                                        independent
# 1040         house                                        independent
#
#          sector  price  price_per_sqft     area  \
# 3679  sector 26  31.50         35000.0   9000.0
# 869   sector 43  27.50         24366.0  11286.0
# 1817  sector 26  26.00         82540.0   3150.0
# 3401  sector 26  26.00         57206.0   4545.0
# 1604  sector 54  25.00         31111.0   8036.0
# 3654  sector 54  24.00        600000.0    400.0
# 1821  sector 26  23.00         25556.0   9000.0
# 1652         4518.0          NaN           1             1           0
# 673             NaN       6000.0           0             1           1
# 592          4518.0          NaN           1             1           1
# 3018         7000.0          NaN           0             0           0
# 1949            NaN      11000.0           0             1           1
# 1040            NaN      10000.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 3679           1       0                2            74
# 869            1       1                0            42
# 1817           1       0                2            72
# 3401           1       1                0           138
# 1604           1       0                1             0
# 3654           1       0                0           122
# 1821           1       0                0           145
# 132            0       0                1            54
# 1018           0       0                0            31
# 1742           1       0                2            97
# 1181           1       0                0           153
# 2768           1       0                0           110
# 1710           1       0                1           122
# 2653           1       0                0           103
# 1652           0       0                0           121
# 673            1       0                0           110
# 592            1       0                0           120
# 3018           0       0                1            30
# 1949           1       0                0            60
# 1040           1       0                0            77

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\Vaibhav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\Vaibhav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 490           flat                unitech vistas        sector 70   9.00
# 1014         house            emaar mgf marbella        sector 66  18.00
# 1189         house                unitech escape        sector 50  10.80
# 1663         house                   independent        sector 26  14.75
# 1817         house                   independent        sector 26  26.00
# 2233         house                  malibu towne        sector 47   8.50
# 2625         house                           nul        sector 28  12.50
# 2678         house        emaar the palm springs        sector 54  14.00
# 2995         house            cloudnine cottages  sohna road road   5.50
# 3401         house                dlf city plots        sector 26  26.00
# 3520         house                   independent        sector 25  16.00
# 3612         house  project housing board colony        sector 31   8.00
# 3654         house        emaar the palm springs        sector 54  24.00
#
#       price_per_sqft    area  \
# 490          57508.0  1565.0
# 1014         55556.0  3240.0
# 1189         60000.0  1800.0
# 1663         51864.0  2844.0
# 1817         82540.0  3150.0
# 2233         53125.0  1600.0
# 2625         51440.0  2430.0
# 2678         62222.0  2250.0
# 2995         55000.0  1000.0
# 3401         57206.0  4545.0
# 3520         59259.0  2700.0
# 3612         63492.0  1260.0
# 3654         66667.0  3600.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 490                  Built Up area: 1565 (145.39 sq.m.)        3         3
# 1014                        Plot area 360(301.01 sq.m.)        4         4
# 1189  Plot area 290(242.48 sq.m.)Built Up area: 250 ...        4         4
# 1663                        Plot area 316(264.22 sq.m.)       16        20
# 1817  Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 2233                 Built Up area: 1600 (148.64 sq.m.)       12        12
# 2625                        Plot area 270(225.75 sq.m.)       16        17
# 2678                        Plot area 250(209.03 sq.m.)        4         5
# 2995                         Plot area 1000(92.9 sq.m.)        3         3
# 3401                        Plot area 505(422.24 sq.m.)        6         7
# 3520  Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 3612                  Built Up area: 140 (117.06 sq.m.)        2         1
# 3654                         Plot area 400(37.16 sq.m.)        5         5
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 490        0       7.0         NaN       Undefined                  NaN
# 1014      3+       3.0        East  Moderately Old                  NaN
# 1189       3       2.0       North  Relatively New                  NaN
# 1663      3+       4.0        East    New Property                  NaN
# 1817      3+       4.0  North-West    New Property                  NaN
# 2233      3+       4.0       North    New Property                  NaN
# 2625      3+       4.0       South  Relatively New                  NaN
# 2678      3+       2.0       North    Old Property                  NaN
# 2995       0       1.0         NaN  Moderately Old                  NaN
# 3401      3+       2.0  North-East    New Property                  NaN
# 3520      3+       4.0        West    New Property                  NaN
# 3612       0       1.0         NaN       Undefined                  NaN
# 3654       2       1.0  North-East    Old Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 490          1565.0          NaN           0             0           0
# 1014         3240.0          NaN           1             1           0
# 1189          250.0        200.0           1             1           1
# 1663         2844.0          NaN           1             1           1
# 1817          400.0        350.0           1             1           1
# 2233         1600.0          NaN           0             0           0
# 2625         2430.0          NaN           1             1           0
# 2678         2250.0          NaN           1             1           0
# 2995         1000.0          NaN           0             0           0
# 3401         4545.0          NaN           1             1           0
# 3520          325.0        300.0           1             1           1
# 3612          140.0          NaN           0             0           0
# 3654          400.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 490            0       0                1             0
# 1014           1       0                2            75
# 1189           1       0                0           103
# 1663           1       0                0           153
# 1817           1       0                2            72
# 2233           0       0                0            99
# 2625           1       1                2           137
# 2678           0       0                0           160
# 2995           0       0                1             0
# 3401           1       1                0           138
# 3520           1       0                2            72
# 3612           0       0                1             0
# 3654           1       0                0           122

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\Vaibhav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 940           flat            ramsons kshitij   sector 95   0.31
# 1235         house                independent   sector 50   5.00
# 2252          flat  signature global solera 2  sector 107   0.51
# 2591          flat          hcbs sports ville  sohna road   0.35
# 2790          flat      signature the roselia   sector 95   0.45
#
#       price_per_sqft      area                           areaWithType  \
# 940              5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 1235           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 2252             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 2591             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2790             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 940         2         2       1       1.0  North-East  Relatively New
# 1235        6         5      3+       2.0         NaN    New Property
# 2252        2         2       1       3.0       North    New Property
# 2591        2         2       2       8.0         NaN  Relatively New
# 2790        2         2       2       2.0  South-West    New Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 940                   NaN            NaN     607936.0           1
# 1235                  NaN            2.0          NaN           1
# 2252                  NaN            NaN     514396.0           0
# 2591                  NaN       737147.0          NaN           0
# 2790                  NaN            NaN     569243.0           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 940              0           0           0       1                1
# 1235             1           0           1       1                0
# 2252             0           0           0       0                1
# 2591             0           0           0       0                2
# 2790             0           0           0       0                1
#
#       luxury_score
# 940             65
# 1235             0
# 2252            44
# 2591            44
# 2790            76

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_9128\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\Vaibhav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471
# Out:
#      property_type                    society           sector  price  \
# 1949         house                independent        sector 26  18.40
# 493          house  ganpati heights apartment        sector 13   1.25
# 3036          flat                 rof ananda        sector 95   0.38
# 1531          flat                 rof ananda        sector 95   0.38
# 3527         house      dlf city plot phase 4        sector 28  13.00
# 1738          flat              pyramid elite        sector 86   0.46
# 2671          flat                 rof ananda        sector 95   0.33
# 2907          flat      signature the serenas       sohna road   0.28
# 3433         house                independent        sector 25   7.30
# 2004          flat            ramsons kshitij        sector 95   0.24
# 3617          flat                 rof ananda        sector 95   0.21
# 3613         house                independent        sector 57   6.25
# 422          house                independent        sector 43   5.50
# 3649          flat                 godrej air        sector 85   2.50
# 207          house       unitech aspen greens        sector 50   6.95
# 1672         house                independent         sector 4   0.85
# 3325          flat                godrej icon       sector 88a   1.75
# 869          house                independent        sector 43  27.50
# 620           flat             m3m golfestate        sector 65  13.20
# 800          house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 1949          1859.0  98978.0
# 493            151.0  82781.0
# 3036            58.0  65517.0
# 1531            58.0  65517.0
# 3527          1992.0  65261.0
# 1738            79.0  58228.0
# 2671            60.0  55000.0
# 2907            57.0  49123.0
# 3433          1560.0  46795.0
# 2004            53.0  45283.0
# 3617            61.0  34426.0
# 3613          2778.0  22498.0
# 422           2716.0  20250.0
# 3649          1379.0  18129.0
# 207           4490.0  15479.0
# 1672           630.0  13492.0
# 3325          1384.0  12645.0
# 869          24366.0  11286.0
# 620          12000.0  11000.0
# 800           5093.0  10799.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1949  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
# 493                        Plot area 115(7692.86 sq.m.)       10         6
# 3036                 Carpet area: 64529 (5994.94 sq.m.)        2         2
# 1531                 Carpet area: 64412 (5984.07 sq.m.)        3         2
# 3527                  Carpet area: 7250 (6061.92 sq.m.)       10        10
# 1738                 Carpet area: 58141 (5401.48 sq.m.)        2         2
# 2671                 Carpet area: 54917 (5101.96 sq.m.)        2         2
in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: '[2356] not found in axis'

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
sns.distplot(df['area'])

# %%
sns.boxplot(x=df['area'])

# %%
df['area'].describe()

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])

# %%
sns.boxplot(x=df['bedRoom'])

# %%
df['bedRoom'].describe()

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape

# %%
sns.distplot(df['bedRoom'])

# %%
sns.boxplot(x=df['bedRoom'])

# %%
df['bedRoom'].describe()

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])

# %%
sns.boxplot(x=df['bathroom'])

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)

# %%
df.head()

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])

# %%
sns.boxplot(x=df['super_built_up_area'])

# %%
df['super_built_up_area'].describe()

# %%
df[df['super_built_up_area'] > 6000]

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])

# %%
sns.boxplot(x=df['built_up_area'])

# %%
df[df['built_up_area'] > 10000]

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])

# %%
sns.boxplot(x=df['carpet_area'])

# %%
df[df['carpet_area'] > 10000]

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]

# %%
df.head()

# %%
sns.distplot(df['luxury_score'])

# %%
sns.boxplot(df['luxury_score'])

# %%
df.shape

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()

# %%
sns.distplot(df['price_per_sqft'])

# %%
sns.boxplot(df['price_per_sqft'])

# %%
df[df['price_per_sqft'] > 42000]

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)

# %%
df[(df['area']/df['bedRoom'])<183]
